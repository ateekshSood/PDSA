# %%
import pandas as pd

# %%
mad_file = pd.read_csv("MAD 1 Level 2 Viva Questions (Responses) - Form Responses 1.csv")
df = pd.DataFrame(mad_file)

# %%
df.shape
# Out:
# (662, 6)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of     Fill this sheet using this form                              Unnamed: 1  \
# 0                               NaN                                     NaN
# 1                         Timestamp  Your Name (if you want, you can share)
# 2                 4/23/2023 9:41:44                       Jeevan Aji George
# 3                4/23/2023 10:51:25                           Aryan Pratap
# 4                4/23/2023 11:28:05                                Himanshu
# ..                              ...                                     ...
# 657              4/20/2026 21:55:28                        Ayush Kumar Sahu
# 658              4/20/2026 22:47:01                                     NaN
# 659              4/20/2026 22:58:27                             Poovarasu G
# 660               4/21/2026 6:59:27                                  Lesgoo
# 661              4/21/2026 13:07:16                                   Kaakh
#
# ...

# %%
df.iloc[1]
# Out:
# Fill this sheet using this form                                                Timestamp
# Unnamed: 1                                        Your Name (if you want, you can share)
# https://forms.gle/769WTWE2NE2dPGx7A                                            Viva Date
# Unnamed: 3                             Viva Proctor ID (the id which was sent to you ...
# Unnamed: 4                             Questions asked by the Viva examiner (Write in...
# Unnamed: 5                             Any suggestions/tips to fellow students for th...
# Name: 1, dtype: object

# %%
df.columns = df.iloc[1]
df = df.iloc[2:]

# %%
df.shape
# Out:
# (660, 6)

# %%
df.columns
# Out:
# Index(['Timestamp', 'Your Name (if you want, you can share)', 'Viva Date',
#        'Viva Proctor ID (the id which was sent to you in email for viva)',
#        'Questions asked by the Viva examiner (Write in points)',
#        'Any suggestions/tips to fellow students for this examiner?'],
#       dtype='object', name=1)

# %%
df.drop(['Timestamp' , 'Your Name (if you want, you can share)' , 
               'Viva Date' , 
               'Any suggestions/tips to fellow students for this examiner?' , 'Viva Proctor ID (the id which was sent to you in email for viva)'] , axis=1 ,
        inplace=True)
# Out:
# /tmp/ipykernel_7183/398231850.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(['Timestamp' , 'Your Name (if you want, you can share)' ,

# %%
df.isnull().sum()
# Out:
# 1
# Questions asked by the Viva examiner (Write in points)    3
# dtype: int64

# %%
df.fillna("")
# Out:
# 1   Questions asked by the Viva examiner (Write in points)
# 2    Project details\nData structures from python -...
# 3    Define ORM, Flask, types of storage, get post ...
# 4    Show MVC in code.\nLimit the username input to...
# 5    About Project\nBootstrap\nDifference between l...
# 6    Incline css update form put get post delete ma...
# ..                                                 ...
# 657  The proctor came 20 minutes late . But it was ...
# 658  1) Asked to setup oppe like camera\n2) Checksu...
# 659  He asked only the questions what we have alrea...
# 660  What is venv\nFrontend n backend validation wi...
# 661  Level1_107\nId\nGithub\nDemo\nWhat's jinja and...
#
# [660 rows x 1 columns]

# %%
df.isnull().sum()
# Out:
# 1
# Questions asked by the Viva examiner (Write in points)    3
# dtype: int64

# %%
df.to_csv('questions.csv' , index=False)
